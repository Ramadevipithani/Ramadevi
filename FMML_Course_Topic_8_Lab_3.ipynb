# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramadevipithani/Ramadevi/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 14:20:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   202MB/s    in 0.3s
#
# 2024-03-27 14:20:07 (202 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2160 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3564 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 204  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 15  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20165   1412.3518v2  Causal models defined in terms of structural e...    cs
# 36208   1309.7393v1  Similarity search is an important function in ...    cs
# 4311    1303.0448v2  Sparse representations using learned dictionar...    cs
# 21730   1210.8429v1  Given a time series of graphs G(t) = (V, E(t))...  stat
# 6485   1702.07552v2  Conditional expectiles are becoming an increas...  stat
# ...             ...                                                ...   ...
# 14965  1604.00077v1  Recurrent neural network architectures combini...    cs
# 9760   cs/0103015v1  In evolutionary algorithms, the fitness of a p...    cs
# 21882   1405.0530v1  We propose a novel non-parametric adaptive ano...  stat
# 23261   1009.1013v1  Dermoscopy is a non-invasive skin imaging tech...    cs
# 36557  1503.01603v1  The generalizability of empirical findings to ...  stat
#
#                                                    title  year  \
# 20165  Appropriate Causal Models and the Stability of...  2014
# 36208  HeteSim: A General Framework for Relevance Mea...  2013
# 4311   Learning Stable Multilevel Dictionaries for Sp...  2013
# 21730  Anomaly Detection in Time Series of Graphs usi...  2012
# 6485   Learning Rates for Kernel-Based Expectile Regr...  2017
# ...                                                  ...   ...
# 14965  Neural Attention Models for Sequence Classific...  2016
# 9760   Fitness Uniform Selection to Preserve Genetic ...  2001
# 21882           A Rank-SVM Approach to Anomaly Detection  2014
# 23261  Automatic Detection of Blue-White Veil and Rel...  2010
# 36557  External Validity: From Do-Calculus to Transpo...  2015
#
#                                                 keywords
# 20165  [structural, equations, representing, knowledg...
# 36208  [similarity, important, applications, measurin...
# 4311   [representations, dictionaries, increasingly, ...
# 21730  [represents, represents, existence, communicat...
# 6485   [conditional, expectiles, increasingly, import...
# ...                                                  ...
# 14965  [recurrent, architectures, combining, attentio...
# 9760   [evolutionary, algorithms, population, increas...
# 21882  [parametric, detection, algorithm, dimensional...
# 23261  [dermoscopy, technique, visualization, pigment...
# 36557  [generalizability, empirical, environments, po...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20165    [structural, equations, representing, knowledg...
# 36208    [similarity, important, applications, measurin...
# 4311     [representations, dictionaries, increasingly, ...
# 21730    [represents, represents, existence, communicat...
# 6485     [conditional, expectiles, increasingly, import...
#                                ...
# 16840    [developing, extractive, summarizer, implement...
# 3358     [introduce, multitask, architecture, integrate...
# 21542    [independent, component, decomposing, statisti...
# 854      [activities, management, information, activiti...
# 13077    [algorithmic, framework, sequential, hypothesi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8777 words.
# Out of those 4566 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8588906f-8a58-4724-99cf-21e1c0c16dbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8588906f-8a58-4724-99cf-21e1c0c16dbe")) {                    Plotly.newPlot(                        "8588906f-8a58-4724-99cf-21e1c0c16dbe",                        [{"x":["additional","maintaining","appropriate","stability","knowledge","intuitions","resulting","variables","relations","definition","regarding","consistent","consideration","assumptions","description","equations","intuitively","unreasonable","causality","normality","different","structural","modification","disambiguate","representing","infinitely","causation","alternate","conservative","necessary","following","constrained","scenarios","measuring","important","increasingly","attributes","characteristics","effectively","efficiently","corresponding","properties","computation","heterogeneous","empirical","relevance","strategies","framework","similarity","applications","relatedness","representations","complexity","theoretic","demonstrate","efficient","generalizable","hierarchical","desirable","simulations","algorithms","asymptotically","clustering","availability","information","processing","development","algorithm","algorithmic","dictionary","dictionaries","necessitates","multilevel","generalization","compressed","procedure","communications","simulation","experimental","inference","existence","invariants","inferential","detection","collection","individual","statistic","weighting","illustrative","represents","anomalies","estimating","calibration","establish","asymmetric","logarithmic","regression","conditional","ingredients","statistical","inequality","analogues","autoregressive","particularly","naturally","interpolation","illustrate","predicted","coefficients","derivations","practically","appealing","approximate","denoising","philosophy","theoretical","filtering","conditions","distributed","classical","cornerstones","dimensional","analytical","underlying","numerical","sufficient","operating","concurrently","presented","frequency","independently","solutions","classification","retrieval","performance","diversity","supervised","categories","effectiveness","distribution","contribution","outperforms","representative","optimized","generation","exploiting","evaluation","introduced","investigate","combination","correlation","measurements","entanglement","cognitive","intension","prototype","entangled","probability","identified","violation","combinations","extension","situations","evaluations","difficulties","performances","architectures","convolutional","computing","gradients","agreement","propagation","volumetric","parameters","essential","ensembles","furthermore","comprehensive","architecture","modalities","corrections","challenge","requiring","segmentation","magnitude","challenging","investigates","competitive","therefore","segmentations","correlated","suggesting","especially","isointense","annotations","quantitative","implementation","allocation","embedding","intricate"],"y":[126,30,77,53,349,2,153,125,83,46,30,74,24,68,71,24,16,3,9,4,760,69,24,5,78,3,3,6,6,69,82,62,93,40,350,45,74,93,111,163,128,201,155,28,151,36,91,538,155,449,15,237,224,41,562,419,4,122,37,39,595,20,146,35,681,301,121,838,36,59,22,2,6,114,21,120,9,77,394,194,24,7,2,335,60,122,7,19,6,45,14,65,10,44,8,22,115,107,7,168,9,2,7,73,71,21,77,41,36,4,15,16,98,43,6,151,70,131,119,102,2,194,32,126,82,66,23,4,206,57,36,168,477,92,866,37,198,65,215,225,81,290,35,54,135,86,252,149,134,136,70,55,2,45,2,18,2,189,40,6,32,91,40,54,36,35,113,379,144,37,15,72,6,241,69,16,143,72,247,31,5,139,44,199,56,264,33,103,128,12,26,11,108,2,67,74,129,33,115,3],"type":"bar"},{"x":["additional","maintaining","appropriate","stability","knowledge", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4566,), (4566, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>What</span> <span style=''>Is</span> <span style=''>Working</span> <span style=''>Memory</span> <span style=''>and</span> <span style=''>Mental</span> <span style=''>Imagery</span> <span style=''>A</span> <span style=''>Robot</span> <span style=''>that</span> <span style=''>Learns</span> <span style=''>to</span> <span style=''>Perform</span> <span style=''>Mental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computations</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>goes</span> <span style=''>back</span> <span style=''>to</span> <span style=''>Turing</span> <span style=''>(1936)</span> <span style=''>and</span> <span style=''>treats</span> <span style=''>his</span> <span style=''>machine</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5517241379310345);'>cognitive</span> <span style=''>model</span> <span style=''>(WDB)</span> <span style=''>where</span> <span style=''>W</span> <span style=''>is</span> <span style=''>an</span> <span style=''>external</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.30370370370370364);'>represented</span> <span style=''>by</span> <span style=''>memory</span> <span style=''>device</span> <span style=''>(the</span> <span style=''>tape</span> <span style=''>divided</span> <span style=''>into</span> <span style=''>squares)</span> <span style=''>and</span> <span style=''>(DB)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>robot</span> <span style=''>that</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sensory</span> <span style=''>motor</span> <span style=''>devices</span> <span style=''>D</span> <span style=''>and</span> <span style=''>the</span> <span style=''>brain</span> <span style=''>B</span> <span style=''>The</span> <span style=''>robots</span> <span style=''>sensory</span> <span style=''>motor</span> <span style=''>devices</span> <span style=''>(the</span> <span style=''>eye</span> <span style=''>the</span> <span style=''>hand</span> <span style=''>and</span> <span style=''>the</span> <span style=''>organ</span> <span style=''>of</span> <span style=''>speech)</span> <span style=''>allow</span> <span style=''>the</span> <span style=''>robot</span> <span style=''>to</span> <span style=''>simulate</span> <span style=''>the</span> <span style=''>work</span> <span style=''>of</span> <span style=''>any</span> <span style=''>Turing</span> <span style=''>machine</span> <span style=''>The</span> <span style=''>robot</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>simulates</span> <span style=''>the</span> <span style=''>internal</span> <span style=''>states</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Turing</span> <span style=''>machine</span> <span style=''>by</span> <span style=''>talking</span> <span style=''>to</span> <span style=''>itself</span> <span style=''>At</span> <span style=''>the</span> <span style=''>stage</span> <span style=''>of</span> <span style=''>training</span> <span style=''>the</span> <span style=''>teacher</span> <span style=''>forces</span> <span style=''>the</span> <span style=''>robot</span> <span style=''>(by</span> <span style=''>acting</span> <span style=''>directly</span> <span style=''>on</span> <span style=''>its</span> <span style=''>motor</span> <span style=''>centers)</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>several</span> <span style=''>examples</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.33099824868651484);'>different</span> <span style=''>input</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.46099290780141844);'>presente ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Projection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>Discrete</span> <span style=''>Choice</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Large</span> <span style=''>Choice</span> <span style=''>Sets</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>sparse</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>tool</span> <span style=''>from</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>choice</span> <span style=''>models</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>choice</span> <span style=''>sets</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Initially</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style=''>into</span> <span style=''>a</span> <span style=''>lower</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>space</span> <span style=''>using</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Subsequently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>proceeds</span> <span style=''>using</span> <span style=''>cyclic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monotonicity</span> <span style=''>moment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>implied</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multinomial</span> <span style=''>choice</span> <span style=''>model</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>and</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>explicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>to</span> <span style=''>be</span> <span style=''>made</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>the</span> <span style=''>random</span> <span style=''>utility</span> <span style=''>errors</span> <span style=''>The</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>justified</span> <span style=''>via</span> <span style=''>the</span> <span style=''>Johnson</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Lindenstrauss</span> <span style=''>Lemma</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.75);'>Completing</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>PMF</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>coupled</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>factorization</span> <span style=''>approach</span> <br/><br/><span style=''>There</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerable</span> <span style=''>interest</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>completing</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>or</span> <span style=''>tensor</span> <span style=''>given</span> <span style=''>only</span> <span style=''>a</span> <span style=''>small</span> <span style=''>fraction</span> <span style=''>(or</span> <span style=''>few</span> <span style=''>linear</span> <span style=''>combinations)</span> <span style=''>of</span> <span style=''>its</span> <span style=''>entries</span> <span style=''>Related</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>have</span> <span style=''>found</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerable</span> <span style=''>success</span> <span style=''>in</span> <span style=''>the</span> <span style=''>area</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommender</span> <span style=''>systems</span> <span style=''>under</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>From</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>point</span> <span style=''>of</span> <span style=''>view</span> <span style=''>the</span> <span style=''>gold</span> <span style=''>standard</span> <span style=''>is</span> <span style=''>to</span> <span style=''>have</span> <span style=''>access</span> <span style=''>to</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pertinent</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3638676844783715);'>variables</span> <span style=''>from</span> <span style=''>which</span> <span style=''>any</span> <span style=''>desired</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.5977653631284916);'>estimator</span> <span style=''>can</span> <span style=''>be</span> <span style=''>readily</span> <span style=''>derived</span> <span style=''>In</span> <span style=''>practice</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3565217391304347);'>distributions</span> <span style=''>are</span> <span style=''>very</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>and</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3009708737864078);'>estimates</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>UCB</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exponential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributions</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>Multi</span> <span style=''>Armed</span> <span style=''>Bandit</span> <span style=''>(MAB)</span> <span style=''>problems</span> <span style=''>A</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>paradigm</span> <span style=''>popular</span> <span style=''>within</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Cognitive</span> <span style=''>Network</span> <span style=''>related</span> <span style=''>topics</span> <span style=''>(eg</span> <span style=''>Spectrum</span> <span style=''>Sensing</span> <span style=''>and</span> <span style=''>Allocation)</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>case</span> <span style=''>where</span> <span style=''>the</span> <span style=''>rewards</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>which</span> <span style=''>is</span> <span style=''>common</span> <span style=''>when</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>Rayleigh</span> <span style=''>fading</span> <span style=''>channels</span> <span style=''>This</span> <span style=''>strategy</span> <span style=''>named</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiplicative</span> <span style=''>Upper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Confidence</span> <span style=''>Bound</span> <span style=''>(MUCB)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associates</span> <span style=''>a</span> <span style=''>utility</span> <span style=''>index</span> <span style=''>to</span> <span style=''>every</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>arm</span> <span style=''>and</span> <span style=''>then</span> <span style=''>selects</span> <span style=''>the</span> <span style=''>arm</span> <span style=''>with</span> <span style=''>the</span> <span style=''>highest</span> <span style=''>index</span> <span style=''>For</span> <span style=''>every</span> <span style=''>arm</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>index</span> <span style=''>is</span> <span style=''>equal</span> <span style=''>to</span> <span style=''>the</span> <span style=''>product</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiplicative</span> <span style=''>factor</span> <span style=''>by</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>mean</span> <span style=''>of</span> <span style=''>the</span> <span style=''>rewards</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>by</span> <span style=''>this</span> <span style=''>arm</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>MUCB</span> <span style=''>policy</span> <span style=''>has</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>is</span> <span style=''>order</span> <span style=''>optimal</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10727013542409124)
# 	representation (0.13399857448325017)
# 	architecture (0.08802565930149679)
# 	information (0.24269422665716323)
# 	segmentation (0.07091945830363507)
# 	experimental (0.14041339985744833)
# 	detection (0.11938702779757662)
# 	different (0.27084818246614395)
# 	recognition (0.12722736992159658)
# 	convolutional (0.13506771204561654)
#
# Some Statistics words are:
# 	stochastic (0.13590772316950853)
# 	variational (0.10330992978936811)
# 	statistical (0.1489468405215647)
# 	variables (0.13440320962888666)
# 	theoretical (0.1444332998996991)
# 	estimation (0.1670010030090271)
# 	distribution (0.18355065195586762)
# 	dimensional (0.17903711133400202)
# 	inference (0.2041123370110331)
# 	regression (0.18355065195586762)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b4191ee4-b19e-44db-8471-9a696cec9ac1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4191ee4-b19e-44db-8471-9a696cec9ac1")) {                    Plotly.newPlot(                        "b4191ee4-b19e-44db-8471-9a696cec9ac1",                        [{"x":["additional","maintaining","appropriate","stability","knowledge","intuitions","resulting","variables","relations","definition","regarding","consistent","consideration","assumptions","description","equations","intuitively","unreasonable","causality","normality","different","structural","modification","disambiguate","representing","infinitely","causation","alternate","conservative","necessary","following","constrained","scenarios","measuring","important","increasingly","attributes","characteristics","effectively","efficiently","corresponding","properties","computation","heterogeneous","empirical","relevance","strategies","framework","similarity","applications","relatedness","representations","complexity","theoretic","demonstrate","efficient","generalizable","hierarchical","desirable","simulations","algorithms","asymptotically","clustering","availability","information","processing","development","algorithm","algorithmic","dictionary","dictionaries","necessitates","multilevel","generalization","compressed","procedure","communications","simulation","experimental","inference","existence","invariants","inferential","detection","collection","individual","statistic","weighting","illustrative","represents","anomalies","estimating","calibration","establish","asymmetric","logarithmic","regression","conditional","ingredients","statistical","inequality","analogues","autoregressive","particularly","naturally","interpolation","illustrate","predicted","coefficients","derivations","practically","appealing","approximate","denoising","philosophy","theoretical","filtering","conditions","distributed","classical","cornerstones","dimensional","analytical","underlying","numerical","sufficient","operating","concurrently","presented","frequency","independently","solutions","classification","retrieval","performance","diversity","supervised","categories","effectiveness","distribution","contribution","outperforms","representative","optimized","generation","exploiting","evaluation","introduced","investigate","combination","correlation","measurements","entanglement","cognitive","intension","prototype","entangled","probability","identified","violation","combinations","extension","situations","evaluations","difficulties","performances","architectures","convolutional","computing","gradients","agreement","propagation","volumetric","parameters","essential","ensembles","furthermore","comprehensive","architecture","modalities","corrections","challenge","requiring","segmentation","magnitude","challenging","investigates","competitive","therefore","segmentations","correlated","suggesting","especially","isointense","annotations","quantitative","implementation","allocation","embedding","intricate","interpretability","incorporate","dirichlet","aggregation","experiments","corresponds","prediction","neighborhood","coherence","structure","extending","correspond","performing","occurring","supervisory","frequently","relationship","nonlinear","describing","involvement","suppliers","protection","reasonable","evolutionary","corporation","behaviour","manufactured","exporting","customers","literature","optimised","resources","determine","financial","independence","previously","optimization","abundance","thousands","techniques","selections","simultaneously","randomized","expensive","possesses","impossible","relatively","unprecedented","effective","observations","challenges","generator","connection","generative","distributi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	generalisations
# 	hypernetwork
# 	hypernetworks
# 	predecessors
# 	effectivity
# 	fragility
# 	attackers
# 	celebrated
# 	frequentist
# 	beforehand
# 	katehakis
# 	forecasters
# 	forecaster
# 	misspecified
# 	selectors
# 	certificate
# 	broadening
# 	sparsistent
# 	penalization
# 	reconcile
# Some words which never appear in Statistics papers:
# 	unreasonable
# 	disambiguate
# 	necessitates
# 	entanglement
# 	intension
# 	entangled
# 	volumetric
# 	isointense
# 	suppliers
# 	exporting
# 	timescale
# 	attentive
# 	keypoints
# 	instructors
# 	extractive
# 	reprojection
# 	photometric
# 	projective
# 	propositional
# 	unsatisfiable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065040152025992e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
